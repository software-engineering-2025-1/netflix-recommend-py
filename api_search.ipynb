# %% [markdown]
# # 백엔드 API에서 유효한 user_id, group_id 범위 탐색
#
# 이 노트북에서는 실제 백엔드 API를 호출해서 user_id, group_id가 몇 번부터 몇 번까지 존재하는지 탐색해보겠습니다.

# %%
# 필요한 라이브러리 및 app.py에서 함수 import
import requests
import os
from dotenv import load_dotenv
import sys

# app.py의 함수들을 사용하기 위해 import
from app import get_user_history_ids, get_group_history_ids

# 환경변수 로드
load_dotenv()

print("필요한 라이브러리 및 함수 import 완료!")
print(f"API_URL: {os.environ.get('API_URL')}")
# Out:
# 필요한 라이브러리 및 함수 import 완료!
# API_URL: http://3.36.57.234:8080/api

# %%
# user_id 범위 탐색 함수 정의
def find_valid_user_ids(start_id=0, max_check=10000):
    """
    start_id부터 시작해서 유효한 user_id들을 찾는 함수
    (시청기록 1개 이상만 유효로 간주)
    """
    valid_users = []
    invalid_users = []
    
    print(f"{start_id}번부터 {start_id + max_check - 1}번까지 user_id 확인 중...")
    
    for user_id in range(start_id, start_id + max_check):
        try:
            history_ids = get_user_history_ids(user_id)
            if len(history_ids) > 0:
                valid_users.append({
                    'user_id': user_id,
                    'history_count': len(history_ids),
                    'history_ids': history_ids[:5] if len(history_ids) > 5 else history_ids  # 처음 5개만 표시
                })
                print(f"✅ User {user_id}: {len(history_ids)}개의 시청 기록")
            else:
                invalid_users.append({'user_id': user_id, 'reason': '시청기록 0개'})
                print(f"❌ User {user_id}: 시청기록 0개")
        except Exception as e:
            invalid_users.append({'user_id': user_id, 'error': str(e)})
            print(f"❌ User {user_id}: {str(e)}")
    
    return valid_users, invalid_users

print("user_id 탐색 함수 정의 완료!")
# Out:
# user_id 탐색 함수 정의 완료!

# %%
# group_id 범위 탐색 함수 정의
def find_valid_group_ids(start_id=0, max_check=100):
    """
    start_id부터 시작해서 유효한 group_id들을 찾는 함수
    (시청기록 1개 이상만 유효로 간주)
    """
    valid_groups = []
    invalid_groups = []
    
    print(f"{start_id}번부터 {start_id + max_check - 1}번까지 group_id 확인 중...")
    
    for group_id in range(start_id, start_id + max_check):
        try:
            history_ids = get_group_history_ids(group_id)
            if len(history_ids) > 0:
                valid_groups.append({
                    'group_id': group_id,
                    'history_count': len(history_ids),
                    'history_ids': history_ids[:5] if len(history_ids) > 5 else history_ids
                })
                print(f"✅ Group {group_id}: {len(history_ids)}개의 시청 기록")
            else:
                invalid_groups.append({'group_id': group_id, 'reason': '시청기록 0개'})
                print(f"❌ Group {group_id}: 시청기록 0개")
        except Exception as e:
            invalid_groups.append({'group_id': group_id, 'error': str(e)})
            print(f"❌ Group {group_id}: {str(e)}")
    
    return valid_groups, invalid_groups

print("group_id 탐색 함수 정의 완료!")
# Out:
# group_id 탐색 함수 정의 완료!

# %%
print("=== 0번부터 시작해서 유효한 group_id 탐색 ===\n")

valid_groups_from_0, invalid_groups_from_0 = find_valid_group_ids(start_id=0, max_check=100)

print(f"\n=== 결과 요약 ===")
print(f"유효한 group_id 개수: {len(valid_groups_from_0)}")
print(f"무효한 group_id 개수: {len(invalid_groups_from_0)}")

if valid_groups_from_0:
    min_group_id = min(group['group_id'] for group in valid_groups_from_0)
    max_group_id = max(group['group_id'] for group in valid_groups_from_0)
    print(f"유효한 group_id 범위: {min_group_id} ~ {max_group_id}")
    print("\n[유효 그룹 샘플 데이터]")
    for group in valid_groups_from_0[:5]:  # 상위 5개만 예시로 출력
        print(f"group_id: {group['group_id']}, 시청기록 개수: {group['history_count']}, history_ids: {group['history_ids']}")
else:
    print("유효한 group_id를 찾지 못했습니다.")

if invalid_groups_from_0:
    print("\n[무효 그룹 id 목록(샘플)]")
    for group in invalid_groups_from_0[:10]:  # 상위 10개만 예시로 출력
        print(group)
# Out:
# === 0번부터 시작해서 유효한 group_id 탐색 ===
#
# 0번부터 99번까지 group_id 확인 중...
# ❌ Group 0: 시청기록 0개
# ✅ Group 1: 28개의 시청 기록
# ✅ Group 2: 28개의 시청 기록
# ✅ Group 3: 28개의 시청 기록
# ✅ Group 4: 28개의 시청 기록
# ✅ Group 5: 28개의 시청 기록
# ✅ Group 6: 28개의 시청 기록
# ✅ Group 7: 28개의 시청 기록
# ❌ Group 8: 시청기록 0개
# ❌ Group 9: 시청기록 0개
# ❌ Group 10: 시청기록 0개
# ❌ Group 11: 시청기록 0개
# ❌ Group 12: 시청기록 0개
# ❌ Group 13: 시청기록 0개
# ❌ Group 14: 시청기록 0개
# ❌ Group 15: 시청기록 0개
# ❌ Group 16: 시청기록 0개
# ❌ Group 17: 시청기록 0개
# ❌ Group 18: 시청기록 0개
# ❌ Group 19: 시청기록 0개
# ❌ Group 20: 시청기록 0개
# ❌ Group 21: 시청기록 0개
# ❌ Group 22: 시청기록 0개
# ❌ Group 23: 시청기록 0개
# ❌ Group 24: 시청기록 0개
# ❌ Group 25: 시청기록 0개
# ❌ Group 26: 시청기록 0개
# ❌ Group 27: 시청기록 0개
# ❌ Group 28: 시청기록 0개
# ❌ Group 29: 시청기록 0개
# ❌ Group 30: 시청기록 0개
# ❌ Group 31: 시청기록 0개
# ❌ Group 32: 시청기록 0개
# ❌ Group 33: 시청기록 0개
# ❌ Group 34: 시청기록 0개
# ❌ Group 35: 시청기록 0개
# ❌ Group 36: 시청기록 0개
# ❌ Group 37: 시청기록 0개
# ❌ Group 38: 시청기록 0개
# ❌ Group 39: 시청기록 0개
# ❌ Group 40: 시청기록 0개
# ❌ Group 41: 시청기록 0개
# ❌ Group 42: 시청기록 0개
# ❌ Group 43: 시청기록 0개
# ❌ Group 44: 시청기록 0개
# ❌ Group 45: 시청기록 0개
# ❌ Group 46: 시청기록 0개
# ❌ Group 47: 시청기록 0개
# ❌ Group 48: 시청기록 0개
# ❌ Group 49: 시청기록 0개
# ❌ Group 50: 시청기록 0개
# ❌ Group 51: 시청기록 0개
# ❌ Group 52: 시청기록 0개
# ❌ Group 53: 시청기록 0개
# ❌ Group 54: 시청기록 0개
# ❌ Group 55: 시청기록 0개
# ❌ Group 56: 시청기록 0개
# ❌ Group 57: 시청기록 0개
# ❌ Group 58: 시청기록 0개
# ❌ Group 59: 시청기록 0개
# ❌ Group 60: 시청기록 0개
# ❌ Group 61: 시청기록 0개
# ❌ Group 62: 시청기록 0개
# ❌ Group 63: 시청기록 0개
# ❌ Group 64: 시청기록 0개
# ❌ Group 65: 시청기록 0개
# ❌ Group 66: 시청기록 0개
# ❌ Group 67: 시청기록 0개
# ❌ Group 68: 시청기록 0개
# ❌ Group 69: 시청기록 0개
# ❌ Group 70: 시청기록 0개
# ❌ Group 71: 시청기록 0개
# ❌ Group 72: 시청기록 0개
# ❌ Group 73: 시청기록 0개
# ❌ Group 74: 시청기록 0개
# ❌ Group 75: 시청기록 0개
# ❌ Group 76: 시청기록 0개
# ❌ Group 77: 시청기록 0개
# ❌ Group 78: 시청기록 0개
# ❌ Group 79: 시청기록 0개
# ❌ Group 80: 시청기록 0개
# ❌ Group 81: 시청기록 0개
# ❌ Group 82: 시청기록 0개
# ❌ Group 83: 시청기록 0개
# ❌ Group 84: 시청기록 0개
# ❌ Group 85: 시청기록 0개
# ❌ Group 86: 시청기록 0개
# ❌ Group 87: 시청기록 0개
# ❌ Group 88: 시청기록 0개
# ❌ Group 89: 시청기록 0개
# ❌ Group 90: 시청기록 0개
# ❌ Group 91: 시청기록 0개
# ❌ Group 92: 시청기록 0개
# ❌ Group 93: 시청기록 0개
# ❌ Group 94: 시청기록 0개
# ❌ Group 95: 시청기록 0개
# ❌ Group 96: 시청기록 0개
# ❌ Group 97: 시청기록 0개
# ❌ Group 98: 시청기록 0개
# ❌ Group 99: 시청기록 0개
#
# === 결과 요약 ===
# 유효한 group_id 개수: 7
# 무효한 group_id 개수: 93
# 유효한 group_id 범위: 1 ~ 7
#
# [유효 그룹 샘플 데이터]
# group_id: 1, 시청기록 개수: 28, history_ids: [1451, 1453, 1455, 1456, 1457]
# group_id: 2, 시청기록 개수: 28, history_ids: [1451, 1453, 1455, 1456, 1457]
# group_id: 3, 시청기록 개수: 28, history_ids: [1451, 1453, 1455, 1456, 1457]
# group_id: 4, 시청기록 개수: 28, history_ids: [1451, 1453, 1455, 1456, 1457]
# group_id: 5, 시청기록 개수: 28, history_ids: [1451, 1453, 1455, 1456, 1457]
#
# [무효 그룹 id 목록(샘플)]
# {'group_id': 0, 'reason': '시청기록 0개'}
# {'group_id': 8, 'reason': '시청기록 0개'}
# {'group_id': 9, 'reason': '시청기록 0개'}
# {'group_id': 10, 'reason': '시청기록 0개'}
# {'group_id': 11, 'reason': '시청기록 0개'}
# {'group_id': 12, 'reason': '시청기록 0개'}
# {'group_id': 13, 'reason': '시청기록 0개'}
# {'group_id': 14, 'reason': '시청기록 0개'}
# {'group_id': 15, 'reason': '시청기록 0개'}
# {'group_id': 16, 'reason': '시청기록 0개'}

# %%
# 0번부터 시작해서 유효한 user_id들 찾기
print("=== 0번부터 시작해서 유효한 user_id 탐색 ===\n")

valid_users_from_0, invalid_users_from_0 = find_valid_user_ids(start_id=0, max_check=100)
print(f"\n=== 결과 요약 ===")
print(f"유효한 user_id 개수: {len(valid_users_from_0)}")
print(f"무효한 user_id 개수: {len(invalid_users_from_0)}")

if valid_users_from_0:
    min_user_id = min(user['user_id'] for user in valid_users_from_0)
    max_user_id = max(user['user_id'] for user in valid_users_from_0)
    print(f"유효한 user_id 범위: {min_user_id} ~ {max_user_id}")
else:
    print("유효한 user_id를 찾지 못했습니다.")
# Out:
# === 0번부터 시작해서 유효한 user_id 탐색 ===
#
# 0번부터 99번까지 user_id 확인 중...
# ❌ User 0: 400 Client Error:  for url: http://3.36.57.234:8080/api/users/0
# ✅ User 1: 28개의 시청 기록
# ✅ User 2: 2개의 시청 기록
# ❌ User 3: 시청기록 0개
# ❌ User 4: 400 Client Error:  for url: http://3.36.57.234:8080/api/users/4
# ❌ User 5: 400 Client Error:  for url: http://3.36.57.234:8080/api/users/5
# ❌ User 6: 400 Client Error:  for url: http://3.36.57.234:8080/api/users/6
# ❌ User 7: 400 Client Error:  for url: http://3.36.57.234:8080/api/users/7
# ❌ User 8: 400 Client Error:  for url: http://3.36.57.234:8080/api/users/8
# ❌ User 9: 400 Client Error:  for url: http://3.36.57.234:8080/api/users/9
# ❌ User 10: 400 Client Error:  for url: http://3.36.57.234:8080/api/users/10
# ❌ User 11: 400 Client Error:  for url: http://3.36.57.234:8080/api/users/11
# ❌ User 12: 400 Client Error:  for url: http://3.36.57.234:8080/api/users/12
# ❌ User 13: 400 Client Error:  for url: http://3.36.57.234:8080/api/users/13
# ❌ User 14: 400 Client Error:  for url: http://3.36.57.234:8080/api/users/14
# ❌ User 15: 400 Client Error:  for url: http://3.36.57.234:8080/api/users/15
# ❌ User 16: 400 Client Error:  for url: http://3.36.57.234:8080/api/users/16
# ❌ User 17: 400 Client Error:  for url: http://3.36.57.234:8080/api/users/17
# ❌ User 18: 400 Client Error:  for url: http://3.36.57.234:8080/api/users/18
# ❌ User 19: 400 Client Error:  for url: http://3.36.57.234:8080/api/users/19
# ❌ User 20: 400 Client Error:  for url: http://3.36.57.234:8080/api/users/20
# ❌ User 21: 400 Client Error:  for url: http://3.36.57.234:8080/api/users/21
# ❌ User 22: 400 Client Error:  for url: http://3.36.57.234:8080/api/users/22
# ❌ User 23: 400 Client Error:  for url: http://3.36.57.234:8080/api/users/23
# ❌ User 24: 400 Client Error:  for url: http://3.36.57.234:8080/api/users/24
# ❌ User 25: 400 Client Error:  for url: http://3.36.57.234:8080/api/users/25
# ❌ User 26: 400 Client Error:  for url: http://3.36.57.234:8080/api/users/26
# ❌ User 27: 400 Client Error:  for url: http://3.36.57.234:8080/api/users/27
# ❌ User 28: 400 Client Error:  for url: http://3.36.57.234:8080/api/users/28
# ❌ User 29: 400 Client Error:  for url: http://3.36.57.234:8080/api/users/29
# ❌ User 30: 400 Client Error:  for url: http://3.36.57.234:8080/api/users/30
# ❌ User 31: 400 Client Error:  for url: http://3.36.57.234:8080/api/users/31
# ❌ User 32: 400 Client Error:  for url: http://3.36.57.234:8080/api/users/32
# ❌ User 33: 400 Client Error:  for url: http://3.36.57.234:8080/api/users/33
# ❌ User 34: 400 Client Error:  for url: http://3.36.57.234:8080/api/users/34
# ❌ User 35: 400 Client Error:  for url: http://3.36.57.234:8080/api/users/35
# ❌ User 36: 400 Client Error:  for url: http://3.36.57.234:8080/api/users/36
# ❌ User 37: 400 Client Error:  for url: http://3.36.57.234:8080/api/users/37
# ❌ User 38: 400 Client Error:  for url: http://3.36.57.234:8080/api/users/38
# ❌ User 39: 400 Client Error:  for url: http://3.36.57.234:8080/api/users/39
# ❌ User 40: 400 Client Error:  for url: http://3.36.57.234:8080/api/users/40
# ❌ User 41: 400 Client Error:  for url: http://3.36.57.234:8080/api/users/41
# ❌ User 42: 400 Client Error:  for url: http://3.36.57.234:8080/api/users/42
# ❌ User 43: 400 Client Error:  for url: http://3.36.57.234:8080/api/users/43
# ❌ User 44: 400 Client Error:  for url: http://3.36.57.234:8080/api/users/44
# ❌ User 45: 400 Client Error:  for url: http://3.36.57.234:8080/api/users/45
# ❌ User 46: 400 Client Error:  for url: http://3.36.57.234:8080/api/users/46
# ❌ User 47: 400 Client Error:  for url: http://3.36.57.234:8080/api/users/47
# ❌ User 48: 400 Client Error:  for url: http://3.36.57.234:8080/api/users/48
# ❌ User 49: 400 Client Error:  for url: http://3.36.57.234:8080/api/users/49
# ❌ User 50: 400 Client Error:  for url: http://3.36.57.234:8080/api/users/50
# ❌ User 51: 400 Client Error:  for url: http://3.36.57.234:8080/api/users/51
# ❌ User 52: 400 Client Error:  for url: http://3.36.57.234:8080/api/users/52
# ❌ User 53: 400 Client Error:  for url: http://3.36.57.234:8080/api/users/53
# ❌ User 54: 400 Client Error:  for url: http://3.36.57.234:8080/api/users/54
# ❌ User 55: 400 Client Error:  for url: http://3.36.57.234:8080/api/users/55
# ❌ User 56: 400 Client Error:  for url: http://3.36.57.234:8080/api/users/56
# ❌ User 57: 400 Client Error:  for url: http://3.36.57.234:8080/api/users/57
# ❌ User 58: 400 Client Error:  for url: http://3.36.57.234:8080/api/users/58
# ❌ User 59: 400 Client Error:  for url: http://3.36.57.234:8080/api/users/59
# ❌ User 60: 400 Client Error:  for url: http://3.36.57.234:8080/api/users/60
# ❌ User 61: 400 Client Error:  for url: http://3.36.57.234:8080/api/users/61
# ❌ User 62: 400 Client Error:  for url: http://3.36.57.234:8080/api/users/62
# ❌ User 63: 400 Client Error:  for url: http://3.36.57.234:8080/api/users/63
# ❌ User 64: 400 Client Error:  for url: http://3.36.57.234:8080/api/users/64
# ❌ User 65: 400 Client Error:  for url: http://3.36.57.234:8080/api/users/65
# ❌ User 66: 400 Client Error:  for url: http://3.36.57.234:8080/api/users/66
# ❌ User 67: 400 Client Error:  for url: http://3.36.57.234:8080/api/users/67
# ❌ User 68: 400 Client Error:  for url: http://3.36.57.234:8080/api/users/68
# ❌ User 69: 400 Client Error:  for url: http://3.36.57.234:8080/api/users/69
# ❌ User 70: 400 Client Error:  for url: http://3.36.57.234:8080/api/users/70
# ❌ User 71: 400 Client Error:  for url: http://3.36.57.234:8080/api/users/71
# ❌ User 72: 400 Client Error:  for url: http://3.36.57.234:8080/api/users/72
# ❌ User 73: 400 Client Error:  for url: http://3.36.57.234:8080/api/users/73
# ❌ User 74: 400 Client Error:  for url: http://3.36.57.234:8080/api/users/74
# ❌ User 75: 400 Client Error:  for url: http://3.36.57.234:8080/api/users/75
# ❌ User 76: 400 Client Error:  for url: http://3.36.57.234:8080/api/users/76
# ❌ User 77: 400 Client Error:  for url: http://3.36.57.234:8080/api/users/77
# ❌ User 78: 400 Client Error:  for url: http://3.36.57.234:8080/api/users/78
# ❌ User 79: 400 Client Error:  for url: http://3.36.57.234:8080/api/users/79
# ❌ User 80: 400 Client Error:  for url: http://3.36.57.234:8080/api/users/80
# ❌ User 81: 400 Client Error:  for url: http://3.36.57.234:8080/api/users/81
# ❌ User 82: 400 Client Error:  for url: http://3.36.57.234:8080/api/users/82
# ❌ User 83: 400 Client Error:  for url: http://3.36.57.234:8080/api/users/83
# ❌ User 84: 400 Client Error:  for url: http://3.36.57.234:8080/api/users/84
# ❌ User 85: 400 Client Error:  for url: http://3.36.57.234:8080/api/users/85
# ❌ User 86: 400 Client Error:  for url: http://3.36.57.234:8080/api/users/86
# ❌ User 87: 400 Client Error:  for url: http://3.36.57.234:8080/api/users/87
# ❌ User 88: 400 Client Error:  for url: http://3.36.57.234:8080/api/users/88
# ❌ User 89: 400 Client Error:  for url: http://3.36.57.234:8080/api/users/89
# ❌ User 90: 400 Client Error:  for url: http://3.36.57.234:8080/api/users/90
# ❌ User 91: 400 Client Error:  for url: http://3.36.57.234:8080/api/users/91
# ❌ User 92: 400 Client Error:  for url: http://3.36.57.234:8080/api/users/92
# ❌ User 93: 400 Client Error:  for url: http://3.36.57.234:8080/api/users/93
# ❌ User 94: 400 Client Error:  for url: http://3.36.57.234:8080/api/users/94
# ❌ User 95: 400 Client Error:  for url: http://3.36.57.234:8080/api/users/95
# ❌ User 96: 400 Client Error:  for url: http://3.36.57.234:8080/api/users/96
# ❌ User 97: 400 Client Error:  for url: http://3.36.57.234:8080/api/users/97
# ❌ User 98: 400 Client Error:  for url: http://3.36.57.234:8080/api/users/98
# ❌ User 99: 400 Client Error:  for url: http://3.36.57.234:8080/api/users/99
#
# === 결과 요약 ===
# 유효한 user_id 개수: 2
# 무효한 user_id 개수: 98
# 유효한 user_id 범위: 1 ~ 2
